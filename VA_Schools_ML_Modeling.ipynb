# %% [markdown]
# <a href="https://colab.research.google.com/github/jmhjasso/ML-Bootcamp-practice/blob/main/VA_Schools_ML_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assigning the data url
data_url = 'https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/Virginia%20Schools%202021.csv'
data_url
# Out:
# 'https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/Virginia%20Schools%202021.csv'

# %%
# Importing pandas package for data processing
import pandas

# %%
# Reading the data from the web URL
data = pandas.read_csv(data_url)

# Displaying the data
data
# Out:
#      Rank                 School  \
# 0       1          Kilmer Center
# 1       2      Thomas Jefferson
# 2       3                  Open
# 3       4    Richmond Community
# 4       5            Grassfield
# ..    ...                    ...
# 322   323             Armstrong
# 323   324              Huguenot
# 324   325          George Wythe
# 325   326                Bryant
# 326   327  Fairfax County Adult
#
#                                             School URL  \
# 0    https://www.schooldigger.com/go/VA/schools/012...
# 1    https://www.schooldigger.com/go/VA/schools/012...
# 2    https://www.schooldigger.com/go/VA/schools/032...
# 3    https://www.schooldigger.com/go/VA/schools/032...
# 4    https://www.schooldigger.com/go/VA/schools/008...
# ..                                                 ...
# 322  https://www.schooldigger.com/go/VA/schools/032...
# 323  https://www.schooldigger.com/go/VA/schools/032...
# 324  https://www.schooldigger.com/go/VA/schools/032...
# ...

# %%
# Displaying the dataset size/shape
data.shape
# Out:
# (327, 27)

# %%
# Displaying the column names
data.columns
# Out:
# Index(['Rank', 'School', 'School URL', 'District', 'District URL', 'Address',
#        'City', 'City URL', 'Zip', 'County', 'Phone', 'Is Title I',
#        'Is Charter', 'Is Magnet', 'Is Virtual', 'Number Students',
#        'Number Full-time Teachers', 'Student/Teacher Ratio',
#        'Percent Free/Disc Lunch', 'Percent African American',
#        'Percent American Indian', 'Percent Asian', 'Percent Hispanic',
#        'Percent Pacific Islander', 'Percent Two or More Races',
#        'Percent White', 'Standard Score'],
#       dtype='object')

# %%
# ML Code snippet 1
# Setting the noise/redundant/missing data variables
ignored_cols  = ['School', 'School URL', 'District URL', 'City URL',
       'Phone']

# %%
# ML Code snippet 2
# Setting categorical cols
cat_cols = ['Rank','District',  'City',
       'Zip', 'County', 'Is Title I', 'Is Charter', 'Is Magnet',
       'Is Virtual']

# %%
# ML Code snippet 3
# Setting the numerical cols
num_cols = ['Number Students', 'Number Full-time Teachers',
       'Student/Teacher Ratio', 'Percent Free/Disc Lunch',
       'Percent African American',
       'Percent American Indian', 'Percent Asian', 'Percent Hispanic',
       'Percent Pacific Islander', 'Percent Two or More Races',
       'Percent White',]

# %%
# ML Code Snippet 4
# Setting the dependent/target/label variable
y = 'Standard Score'

# %%
# ML Code snippet 5
# Installing Pycaret for Automated ML
# !pip install -U --pre pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 35.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 66.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 73.7 MB/s eta 0:00:00
# ...

# %%
# ML Code snippet 6
# Importing Pycaret and setting/configuring the ML experiment
from pycaret.regression import *

regression_model_setup = setup(data,
      target = y,
      categorical_features = cat_cols,
      numeric_features = num_cols,
      ignore_features = ignored_cols)
# Out:
# <style type="text/css">
# #T_a12e2_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a12e2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a12e2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a12e2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a12e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a12e2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a12e2_row0_col1" class="data row0 col1" >3023</td>
#     </tr>
#     <tr>
#       <th id="T_a12e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a12e2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a12e2_row1_col1" class="data row1 col1" >Standard Score</td>
#     </tr>
#     <tr>
#       <th id="T_a12e2_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# ML Code snippet 7
# Invoking ML algorithms
compare_models()
# Out:
# <style type="text/css">
# #T_32bac th {
#   text-align: left;
# }
# #T_32bac_row0_col0, #T_32bac_row1_col0, #T_32bac_row1_col1, #T_32bac_row1_col2, #T_32bac_row1_col3, #T_32bac_row1_col4, #T_32bac_row1_col5, #T_32bac_row1_col6 {
#   text-align: left;
# }
# #T_32bac_row0_col1, #T_32bac_row0_col2, #T_32bac_row0_col3, #T_32bac_row0_col4, #T_32bac_row0_col5, #T_32bac_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_32bac_row0_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_32bac_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_32bac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32bac_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_32bac_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_32bac_level0_col2" class="col_heading level0 col2" >MSE</th>
# ...
